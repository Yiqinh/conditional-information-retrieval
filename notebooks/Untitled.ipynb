# %%
# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import numpy as np 
import matplotlib.pyplot as plt
plt.xkcd()
x = np.linspace(0, 10)
y1 = x * np.sin(x)
y2 = x * np.cos(x)

plt.fill(x, y1, 'red', alpha=0.4)
plt.fill(x, y2, 'blue', alpha=0.4)
plt.xlabel('x axis yo!')
plt.ylabel("I don't even know")
# Out:
# Text(0, 0.5, "I don't even know")
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# ...

# %%
! ls $HOME/.matplotlib/
# Out:
# fontlist-v390.json

# %%
matplotlib.rcParams.update({
    'font.sans-serif': 'Comic Neue',
    'font.family': 'sans-serif',
    'font.weight': 'normal',
    'axes.labelweight': 'normal',
    'axes.titleweight': 'normal',
})

matplotlib.rcParams.update({
    'font.sans-serif': 'xkcd',
    'font.family': 'sans-serif',
    'font.weight': 'normal',
    'axes.labelweight': 'normal',
    'axes.titleweight': 'normal',
})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 matplotlib.rcParams.update({
#       2     'font.sans-serif': 'Comic Neue',
#       3     'font.family': 'sans-serif',
#       4     'font.weight': 'normal',
#       5     'axes.labelweight': 'normal',
#       6     'axes.titleweight': 'normal',
#       7 })
#       9 matplotlib.rcParams.update({
#      10     'font.sans-serif': 'xkcd',
#      11     'font.family': 'sans-serif',
#    (...)
#      14     'axes.titleweight': 'normal',
#      15 })
#
# NameError: name 'matplotlib' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.xkcd()
plt.plot(np.sin(np.linspace(0, 10)))
plt.title('Whoo Hoo!!!')
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Text(0.5, 1.0, 'Whoo Hoo!!!')
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
import json
json.load(open('/Users/spangher/.matplotlib/fontlist-v390.json'))
# Out:
# {'_version': 390,
#  '_FontManager__default_weight': 'normal',
#  'default_size': None,
#  'defaultFamily': {'ttf': 'DejaVu Sans', 'afm': 'Helvetica'},
#  'afmlist': [{'fname': 'fonts/pdfcorefonts/Courier-Bold.afm',
#    'name': 'Courier',
#    'style': 'normal',
#    'variant': 'normal',
#    'weight': 'bold',
#    'stretch': 'normal',
#    'size': 'scalable',
#    '__class__': 'FontEntry'},
#   {'fname': 'fonts/afm/pcrr8a.afm',
#    'name': 'Courier',
#    'style': 'normal',
#    'variant': 'normal',
#    'weight': 'medium',
#    'stretch': 'normal',
#    'size': 'scalable',
#    '__class__': 'FontEntry'},
#   {'fname': 'fonts/pdfcorefonts/Helvetica-BoldOblique.afm',
#    'name': 'Helvetica',
#    'style': 'italic',
#    'variant': 'normal',
#    'weight': 'bold',
#    'stretch': 'normal',
#    'size': 'scalable',
#    '__class__': 'FontEntry'},
#   {'fname': 'fonts/afm/cmsy10.afm',
#    'name': 'Computer Modern',
#    'style': 'italic',
#    'variant': 'normal',
# ...

# %%
! fc-list | grep 'Comic Neu'

# %%
! fc-list | grep 'Humor'
# Out:
# /Library/Fonts/Humor-Sans.ttf: Humor Sans:style=Regular
# /Users/spangher/Library/Fonts/Humor-Sans.ttf: Humor Sans:style=Regular

# %%
import matplotlib
matplotlib.font_manager._rebuild()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 import matplotlib
# ----> 2 matplotlib.font_manager._rebuild()
#
# AttributeError: module 'matplotlib.font_manager' has no attribute '_rebuild'
